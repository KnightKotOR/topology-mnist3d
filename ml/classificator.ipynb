# %% [markdown]
# #### 0. Imports

# %%
from ml.optuna_search import ModelOptimization

# %% [markdown]
# #### 1. Load data

# %%
X_train = []
X_val = []

y_train = []
y_val = []

# %% [markdown]
# #### 2. Params Optimization

# %%
model_list = ("CatBoostRegressor","XGBRegressor",
			  "RandomForestRegressor","HistGradientBoostingRegressor",
			  "ElasticNet")

search = ModelOptimization(model_list)
search.fit(X_train, y_train, X_val, y_val, n_trials=15, n_startup_trials=5)
